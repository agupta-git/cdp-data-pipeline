# %%
import cml.data_v1 as cmldata
# name of the virtual warehouse that you want to connect to
CONNECTION_NAME = "pse-demo"

# establish connection
conn = cmldata.get_connection(
    CONNECTION_NAME, {"USERNAME": "angupta", "PASSWORD": "Cloudera@2022"}
)

SQL_SHOW_DB = "show databases"
dataframe_a = conn.get_pandas_dataframe(SQL_SHOW_DB)
print(dataframe_a)
print('----------------------------------------------------------------------------------------------- \n')

SQL_SHOW_COVID_DEMOGRAPHIC_RATE_CUMULATIVE = "select * from cdph.covid_demo_rate_cumulative a limit 10"
dataframe_b = conn.get_pandas_dataframe(SQL_SHOW_COVID_DEMOGRAPHIC_RATE_CUMULATIVE)
print(dataframe_b)
print('----------------------------------------------------------------------------------------------- \n')

SQL_SHOW_MEMBER_PROFILE = "select * from member.member_profile a limit 10"
dataframe_c = conn.get_pandas_dataframe(SQL_SHOW_MEMBER_PROFILE)
print(dataframe_c)
print('----------------------------------------------------------------------------------------------- \n')
# Out:
#         database_name
# 0                cdph
# 1             default
# 2             factory
# 3  information_schema
# 4           marketing
# 5              member
# 6             reports
# 7               sales
# 8                 sys
# -----------------------------------------------------------------------------------------------
#
#   a.county a.demographic_set                  a.demographic_set_category  \
# 0  Alameda    race_ethnicity                            African American
# 1  Alameda    race_ethnicity                             American Indian
# 2  Alameda    race_ethnicity                              Asian American
# 3  Alameda    race_ethnicity                                      Latino
# 4  Alameda    race_ethnicity                                  Multi-Race
# 5  Alameda    race_ethnicity  Native Hawaiian and other Pacific Islander
# 6  Alameda    race_ethnicity                                       Other
# ...
